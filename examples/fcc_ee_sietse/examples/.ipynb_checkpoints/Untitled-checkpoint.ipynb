# %%
with wrap_file(response, size) as file:
    for line in file:
        print(line.decode("utf-8"), end="")
        sleep(0.1)
# Out:
#   Cell In[1], line 2
#     from rich-progress import track for 1 in track(range(20),
#              ^
# SyntaxError: invalid syntax
